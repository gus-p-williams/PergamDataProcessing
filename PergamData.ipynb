# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# \11_19_25
csv_file_path = './Code/2025-11-19-vernaldata.csv'
print(csv_file_path)
meth_df = pd.read_csv(csv_file_path)
print(meth_df.head())
print(meth_df.columns)
meth_df.drop('ALT:ID', inplace=True)
# Out:
# ./Code/2025-11-19-vernaldata.csv
#         Elapsed        Date     Time  Pitch  Roll  Heading   Latitude  \
# 0  1.763580e+12  11/19/2025  42:32.1    NaN   NaN      NaN        NaN
# 1  1.763580e+12  11/19/2025  42:32.2   0.62 -1.49   102.72  40.460352
# 2  1.763580e+12  11/19/2025  42:32.3   0.61 -1.49   102.71  40.460352
# 3  1.763580e+12  11/19/2025  42:32.4   0.62 -1.49   102.76  40.460352
# 4  1.763580e+12  11/19/2025  42:32.5   0.63 -1.49   102.75  40.460352
#
#     Longitude  Altitude  Next WP  Velocity RTK Status  Latitude RTK  \
# 0         NaN       NaN      NaN       NaN        NaN           NaN
# 1 -109.565272       0.0      NaN      0.00        OFF           NaN
# 2 -109.565272       0.0      NaN      0.00        OFF           NaN
# 3 -109.565272       0.0      NaN      0.00        OFF           NaN
# 4 -109.565272       0.0      NaN      0.01        OFF           NaN
#
#    Longitude RTK  Altitude RTK  ALT:Altitude                         ALT:ID  \
# ...
